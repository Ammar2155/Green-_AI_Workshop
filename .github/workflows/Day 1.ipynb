# %%
print("Hello World")
name= input("Enter your name")
# Out:
# Hello World
# Enter your namem

# %%
city_name="Chandrapur"
print(f"City Name : {city_name}")
# Out:
# City Name : Chandrapur

# %%
carbon_footprint=450.25
print(f"Carbon Footprint : {carbon_footprint} kg CO2")
# Out:
# Carbon Footprint : 450.25 kg CO2

# %%
if(carbon_footprint>400):
    print("Carbon Footprint is high")
else:
    print("Carbon Footprint is low")
# Out:
# Carbon Footprint is high

# %%
is_sustainable=carbon_footprint<400
print(f"Is Sustainable ?{is_sustainable}")
# Out:
# Is Sustainable ?False

# %%
weekly_temperatures={25,27,28,26,24,30,29}
print(f"Weekly Temperature : {weekly_temperatures}")
print(25 in weekly_temperatures)
# Out:
# Weekly Temperature : {24, 25, 26, 27, 28, 29, 30}
# True

# %%
city_data={"name":"Chandrapur","temperature" : 45,"carbon_footprint":500.75,"is_sustainable":True}
print(f"City Data : {city_data}")
# Out:
# City Data : {'name': 'Chandrapur', 'temperature': 45, 'carbon_footprint': 500.75, 'is_sustainable': True}

# %%
def even_odd_checker(number):
    if number % 2 == 0:
        print(f"{number} is even.")
    else:
        print(f"{number} is odd.")
even_odd_checker(4)
even_odd_checker(7)
# Out:
# 4 is even.
# 7 is odd.

# %%
def calculator():
    """Performs basic arithmetic operations."""

    while True:
        print("\nSelect operation:")
        print("1. Add")
        print("2. Subtract")
        print("3. Multiply")
        print("4. Divide")
        print("5. Exit")

        try:
            choice = int(input("Enter choice(1/2/3/4/5): "))
        except ValueError:
            print("Invalid input. Please enter a number.")
            continue

        if choice == 5:
            break

        if choice not in [1, 2, 3, 4]:
            print("Invalid input. Please enter a number between 1 and 5.")
            continue

        try:
            num1 = float(input("Enter first number: "))
            num2 = float(input("Enter second number: "))
        except ValueError:
            print("Invalid input. Please enter numbers.")
            continue

        if choice == 1:
            print(num1, "+", num2, "=", num1 + num2)
        elif choice == 2:
            print(num1, "-", num2, "=", num1 - num2)
        elif choice == 3:
            print(num1, "*", num2, "=", num1 * num2)
        elif choice == 4:
            if num2 == 0:
                print("Division by zero error!")
            else:
                print(num1, "/", num2, "=", num1 / num2)

calculator()6
# Out:
# Select operation:
# 1. Add
# 2. Subtract
# 3. Multiply
# 4. Divide
# 5. Exit
# Enter choice(1/2/3/4/5): 1
# Enter first number: 5
# Enter second number: 6
# 5.0 + 6.0 = 11.0
#
# Select operation:
# 1. Add
# 2. Subtract
# 3. Multiply
# 4. Divide
# 5. Exit
# Enter choice(1/2/3/4/5): 5

# %% [markdown]
# DAY 2

# %%
def greet(name):
  print("Hello ",name)

# %%
greet("Ammar")
# Out:
# Hello  Ammar

# %%
list1=[1,2,3,4,5]
s="qwerty"
x=len(s)
y=len(list1)
print(x,y)
# Out:
# 6 5

# %%
def add(a,b):
  c=a+b
  return c

# %%
add(3,4)
print(c)
# Out:
# 5

# %%
func = lambda a,b : a+b
print(func(5,4))
# Out:
# 9

# %%
x = int(input("Enter year"))
func1 = lambda x: (x%100!=0 and x%4==0) or x%400==0
if(func1(x)):
  print("Leap Year")
else:
  print("Not a Leap Year")
# Out:
# Enter year2024
# Leap Year
