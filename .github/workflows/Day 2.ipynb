# %%
climate_data = [
    {"city": "City A", "temperature": 25, "carbon_footprint": 500},
    {"city": "City B", "temperature": 30, "carbon_footprint": 350},
    {"city": "City C", "temperature": 22, "carbon_footprint": 600},
    {"city": "City D", "temperature": 15, "carbon_footprint": 200},
    {"city": "City E", "temperature": 28, "carbon_footprint": 450},
]
high_temp_threshold=26
high_temp_cities=[city for city in climate_data if city["temperature"]>high_temp_threshold]
print("Cities with high temperature (>26C)")
for city in high_temp_cities:
    print(f"city['city']}- {city['temperature']}C)
total carbon =0
for city in climate_data:
          total_carbon+=city["Carbon_footprint"]
print(total_carbon)
average=total_carbon/len(climate_data)
print(average)
# Out:
#   File "<ipython-input-1-42cfc54dadaa>", line 6
#     {"city": "City E", "temperature": 28, "carbon_footprint": 450},
#                                                              ^
# SyntaxError: invalid non-printable character U+00A0

# %%
sustainability_threshold=400
sustainable_cities=list(filter(lambda city: city["carbon footprint"]<sustainability_threshold,climate_data))
print("\nSustainable Cities (carbon footprint< 400 kg CO2):")
for city in sustainable_cities:
  print(f"{city['city']-city['carbon_footprint']}kd CO2")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-7ca22dffee3f> in <cell line: 2>()
#       1 sustainability_threshold=400
# ----> 2 sustainable_cities=list(filter(lambda city: city["carbon footprint"]<sustainability_threshold,climate_data))
#       3 print("\nSustainable Cities (carbon footprint< 400 kg CO2):")
#       4 for city in sustainable_cities:
#       5   print(f"{city['city']-city['carbon_footprint']}kd CO2")
#
# NameError: name 'climate_data' is not defined

# %%
highest_footprint_city=max(climate_data,key=lambda city:city["carbon_footprint"])
print("\nCity with the highest carbon footprint:")
print(f"{highest_footprint_city['city']}-{highest_footprint_city['carbon_footprint']} kg CO2")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-89340df2441f> in <cell line: 1>()
# ----> 1 highest_footprint_city=max(climate_data,key=lambda city:city["carbon_footprint"])
#       2 print("\nCity with the highest carbon footprint:")
#       3 print(f"{highest_footprint_city['city']}-{highest_footprint_city['carbon_footprint']} kg CO2")
#
# NameError: name 'climate_data' is not defined

# %%
def calculate_carbon_footprint(energy_consumption, emission_factors):
   return energy_consumption*emission_factors

# %%
energy_consumption=1000
emission_factor=0.475
carbon_footprint=calculate_carbon_footprint(energy_consumption,emission_factor)
print(f"Carbon Footprint : {carbon_footprint} kg CO2")
# Out:
# Carbon Footprint : 475.0 kg CO2

# %%
import pandas as pd
renewable_sources = ["Solar", "Wind", "Hydropower", "Geothermal", "Biomass"]

# Sample green technology project data (for DataFrame)
data = {
    "Project": ["Solar Farm A", "Wind Turbine X", "Hydropower Y", "Solar Roof Z", "Geothermal Plant P"],
    "Technology": ["Solar", "Wind", "Hydropower", "Solar", "Geothermal"],
    "Capacity (MW)": [150, 300, 200, 50, 100],  # Megawatts
    "Cost (Million $)": [200, 400, 350, 100, 250],  # Project cost
    "Location": ["California", "Texas", "Washington", "Nevada", "Idaho"],
    "Completion Year": [2023, 2024, 2022,2025, 2023]
}

# %%
renewable_series=pd.Series(renewable_sources)
print(renewable_series)
# Out:
# 0         Solar
# 1          Wind
# 2    Hydropower
# 3    Geothermal
# 4       Biomass
# dtype: object

# %%
projects_df=pd.DataFrame(data)
projects_df.head()
#print(projects_df)
# Out:
#               Project  Technology  Capacity (MW)  Cost (Million $)  \
# 0        Solar Farm A       Solar            150               200
# 1      Wind Turbine X        Wind            300               400
# 2        Hydropower Y  Hydropower            200               350
# 3        Solar Roof Z       Solar             50               100
# 4  Geothermal Plant P  Geothermal            100               250
#
#      Location  Completion Year
# 0  California             2023
# 1       Texas             2024
# 2  Washington             2022
# 3      Nevada             2025
# 4       Idaho             2023

# %%
projects_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Project           5 non-null      object
#  1   Technology        5 non-null      object
#  2   Capacity (MW)     5 non-null      int64
#  3   Cost (Million $)  5 non-null      int64
#  4   Location          5 non-null      object
#  5   Completion Year   5 non-null      int64
# dtypes: int64(3), object(3)
# memory usage: 368.0+ bytes

# %%
projects_df
# Out:
#        Capacity (MW)  Cost (Million $)  Completion Year
# count        5.00000          5.000000         5.000000
# mean       160.00000        260.000000      2023.400000
# std         96.17692        119.373364         1.140175
# min         50.00000        100.000000      2022.000000
# 25%        100.00000        200.000000      2023.000000
# 50%        150.00000        250.000000      2023.000000
# 75%        200.00000        350.000000      2024.000000
# max        300.00000        400.000000      2025.000000

# %%
high_capacity_projects=projects_df[projects_df["Capacity (MW)"]>100]
print(high_capacity_projects)
# Out:
#           Project  Technology  Capacity (MW)  Cost (Million $)    Location  \
# 0    Solar Farm A       Solar            150               200  California
# 1  Wind Turbine X        Wind            300               400       Texas
# 2    Hydropower Y  Hydropower            200               350  Washington
#
#    Completion Year
# 0             2023
# 1             2024
# 2             2022

# %%
projects_df["Cost per MW"]=projects_df["Cost (Million $)"]/projects_df["Capacity (MW)"]
projects_df.head()
# Out:
#               Project  Technology  Capacity (MW)  Cost (Million $)  \
# 0        Solar Farm A       Solar            150               200
# 1      Wind Turbine X        Wind            300               400
# 2        Hydropower Y  Hydropower            200               350
# 3        Solar Roof Z       Solar             50               100
# 4  Geothermal Plant P  Geothermal            100               250
#
#      Location  Completion Year  Cost per MW
# 0  California             2023     1.333333
# 1       Texas             2024     1.333333
# 2  Washington             2022     1.750000
# 3      Nevada             2025     2.000000
# 4       Idaho             2023     2.500000

# %%
total_capacity=projects_df["Capacity (MW)"].sum()
print(total_capacity)
total_cost=projects_df["Cost (Million $)"].sum()
print(total_cost)
# Out:
# 800
# 1300

# %%
gropued_data=projects_df.groupby("Technology")["Capacity (MW)"].sum()
print(gropued_data)
# Out:
# Technology
# Geothermal    100
# Hydropower    200
# Solar         200
# Wind          300
# Name: Capacity (MW), dtype: int64

# %%
import numpy as np
energy_consumption=np.array([1200,3400,2900,1800,2500])
print("Energy Consumption:")
print(energy_consumption)
# Out:
# Energy Consumption:
# [1200 3400 2900 1800 2500]

# %%
mylist=[[1,2,3,],[4,5,6],[7,8,9]]
np.array(mylist)
print(mylist)
# Out:
# [[1, 2, 3], [4, 5, 6], [7, 8, 9]]

# %%
np.random.rand(5)
np.random.rand(5,5)
np.random.randn(5)
np.random.randn(5,5)
# Out:
# array([[ 0.59910029,  1.10548429, -1.24050113, -2.36065285, -0.1030312 ],
#        [-0.03005713,  0.05909269, -1.28847929,  0.63853115,  1.49475965],
#        [-1.10732139,  0.9441063 , -0.7843737 , -0.04620565, -0.94934687],
#        [ 1.3968291 , -0.17724379,  1.11880413,  0.843651  ,  0.13534483],
#        [ 0.37588702, -0.63350705,  0.45172096, -1.07859319,  1.19654546]])

# %%
import numpy as np
random_integers = np.random.randint(0, 10, size=5)
print("Random integers:", random_integers)
unique_elements = np.unique(random_integers)
print("Unique elements:", unique_elements)
array1 = np.array([1, 2, 3])
array2 = np.array([4, 5, 6])
dot_product = np.dot(array1, array2)
print("Dot product:", dot_product)
powered_array = np.power(array1, 2)
print("Powered array:", powered_array)
sqrt_array = np.sqrt(array1)
print("Square root array:", sqrt_array)
ones_array = np.ones(5)
print("Ones array:", ones_array)
zeros_array = np.zeros((2,3))
print("Zeros array:\n", zeros_array)
max_value = np.max(array1)
print("Max value:", max_value)
arange_array = np.arange(0, 10, 2)
print("Arange array:",arange_array)
# Out:
# Random integers: [9 9 3 5 3]
# Unique elements: [3 5 9]
# Dot product: 32
# Powered array: [1 4 9]
# Square root array: [1.         1.41421356 1.73205081]
# Ones array: [1. 1. 1. 1. 1.]
# Zeros array:
#  [[0. 0. 0.]
#  [0. 0. 0.]]
# Max value: 3
# Arange array: [0 2 4 6 8]

# %%
total_consumption=np.sum(energy_consumption)
print(total_consumption)
average_consumption=np.mean(energy_consumption)
print(average_consumption)
# Out:
# 11800
# 2360.0

# %%
reshaped_array=energy_consumption.reshape((5,1))
print(reshaped_array)
# Out:
# [[1200]
#  [3400]
#  [2900]
#  [1800]
#  [2500]]

# %%
std_deviation=np.std(energy_consumption)
print(std_deviation)
# Out:
# 781.2809993849844

# %%
import pandas as pd
import numpy as np
data = {
    "Energy Source": ["Solar", "Wind", "Hydropower", "Geothermal", "Biomass", "Nuclear"],
    "Energy Consumption (MWh)": [1200, np.nan, 2900, np.nan, 2500, 3200],
    "Cost (Million $)": [200, 400, np.nan, 150, 250, np.nan]
}
energy_df = pd.DataFrame(data)
print(energy_df)
print(energy_df)
# Out:
#   Energy Source  Energy Consumption (MWh)  Cost (Million $)
# 0         Solar                    1200.0             200.0
# 1          Wind                       NaN             400.0
# 2    Hydropower                    2900.0               NaN
# 3    Geothermal                       NaN             150.0
# 4       Biomass                    2500.0             250.0
# 5       Nuclear                    3200.0               NaN
#   Energy Source  Energy Consumption (MWh)  Cost (Million $)
# 0         Solar                    1200.0             200.0
# 1          Wind                       NaN             400.0
# 2    Hydropower                    2900.0               NaN
# 3    Geothermal                       NaN             150.0
# 4       Biomass                    2500.0             250.0
# 5       Nuclear                    3200.0               NaN

# %%
cleaned_df=energy_df.dropna()
cleaned_df.head()
# Out:
#   Energy Source  Energy Consumption (MWh)  Cost (Million $)
# 0         Solar                    1200.0             200.0
# 4       Biomass                    2500.0             250.0

# %%
ec_mean=energy_df["Energy Consumption (MWh)"].mean()
energy_df["Energy Consumption (MWh)"].fillna(ec_mean,inplace=True)
print(energy_df)
energy_df.head()
# Out:
#   Energy Source  Energy Consumption (MWh)  Cost (Million $)
# 0         Solar                    1200.0             200.0
# 1          Wind                    2450.0             400.0
# 2    Hydropower                    2900.0               NaN
# 3    Geothermal                    2450.0             150.0
# 4       Biomass                    2500.0             250.0
# 5       Nuclear                    3200.0               NaN
# <ipython-input-6-34ba1205425a>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   energy_df["Energy Consumption (MWh)"].fillna(ec_mean,inplace=True)
#   Energy Source  Energy Consumption (MWh)  Cost (Million $)
# 0         Solar                    1200.0             200.0
# 1          Wind                    2450.0             400.0
# 2    Hydropower                    2900.0               NaN
# 3    Geothermal                    2450.0             150.0
# 4       Biomass                    2500.0             250.0

# %%
forward_fill_df=energy_df.fillna(method="ffill")
print(forwarf_fill_df)
forward_fill_df.head()
# Out:
#   Energy Source  Energy Consumption (MWh)  Cost (Million $)
# 0         Solar                    1200.0             200.0
# 1          Wind                    2450.0             400.0
# 2    Hydropower                    2900.0             400.0
# 3    Geothermal                    2450.0             150.0
# 4       Biomass                    2500.0             250.0
# 5       Nuclear                    3200.0             250.0
# <ipython-input-9-265503b53d05>:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   forward_fill_df=energy_df.fillna(method="ffill")
#   Energy Source  Energy Consumption (MWh)  Cost (Million $)
# 0         Solar                    1200.0             200.0
# 1          Wind                    2450.0             400.0
# 2    Hydropower                    2900.0             400.0
# 3    Geothermal                    2450.0             150.0
# 4       Biomass                    2500.0             250.0

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
energy_df[["Energy Consumption (MWh)", "Cost (Million $)"]] = scaler.fit_transform(energy_df[["Energy Consumption (MWh)", "Cost (Million $)"]])
print(energy_df)
# Out:
#   Energy Source  Energy Consumption (MWh)  Cost (Million $)
# 0         Solar                     0.000               0.2
# 1          Wind                     0.625               1.0
# 2    Hydropower                     0.850               NaN
# 3    Geothermal                     0.625               0.0
# 4       Biomass                     0.650               0.4
# 5       Nuclear                     1.000               NaN

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
energy_df[["Energy Consumption (MWh)", "Cost (Million $)"]] = scaler.fit_transform(energy_df[["Energy Consumption (MWh)", "Cost (Million $)"]])
print(energy_df)
# Out:
#   Energy Source  Energy Consumption (MWh)  Cost (Million $)
# 0         Solar             -2.005893e+00         -0.534522
# 1          Wind              3.563181e-16          1.603567
# 2    Hydropower              7.221213e-01               NaN
# 3    Geothermal              3.563181e-16         -1.069045
# 4       Biomass              8.023570e-02          0.000000
# 5       Nuclear              1.203536e+00               NaN

# %%
energy_encoded_df=pd.get_dummies(energy_df,columns=["Energy Source"])
print(energy_encoded_df)
energy_encoded_df.head()
# Out:
#    Energy Consumption (MWh)  Cost (Million $)  Energy Source_Biomass  \
# 0             -2.005893e+00         -0.534522                  False
# 1              3.563181e-16          1.603567                  False
# 2              7.221213e-01               NaN                  False
# 3              3.563181e-16         -1.069045                  False
# 4              8.023570e-02          0.000000                   True
# 5              1.203536e+00               NaN                  False
#
#    Energy Source_Geothermal  Energy Source_Hydropower  Energy Source_Nuclear  \
# 0                     False                     False                  False
# 1                     False                     False                  False
# 2                     False                      True                  False
# 3                      True                     False                  False
# 4                     False                     False                  False
# 5                     False                     False                   True
#
#    Energy Source_Solar  Energy Source_Wind
# 0                 True               False
# 1                False                True
# 2                False               False
# 3                False               False
# 4                False               False
# 5                False               False
#    Energy Consumption (MWh)  Cost (Million $)  Energy Source_Biomass  \
# 0             -2.005893e+00         -0.534522                  False
# 1              3.563181e-16          1.603567                  False
# 2              7.221213e-01               NaN                  False
# 3              3.563181e-16         -1.069045                  False
# 4              8.023570e-02          0.000000                   True
#
#    Energy Source_Geothermal  Energy Source_Hydropower  Energy Source_Nuclear  \
# 0                     False                     False                  False
# 1                     False                     False                  False
# 2                     False                      True                  False
# 3                      True                     False                  False
# 4                     False                     False                  False
#
#    Energy Source_Solar  Energy Source_Wind
# 0                 True               False
# 1                False                True
# 2                False               False
# 3                False               False
# 4                False               False

# %%
import matplotlib.pyplot as plt
months=['jan','feb','mar','apr','may','jun']
energy_consumption=[1200,3400,2900,1800,2500,3000]
plt.plot(months,energy_consumption)
plt.title('Energy Consumption over 6 months')
plt.xlabel('Months')
plt.ylabel('Energy Consumption (MWh)')
plt.show()

# %%
energy_sources=['Solar','Wind','Hydropower','Geothermal','Biomass']
energy_consumption=[1200,3400,2900,1800,2500]
plt.bar(energy_sources,energy_consumption)
plt.title('Energy Consumption by Source')
plt.xlabel('Energy Source')
plt.ylabel('Energy Consumption (MWh)')
plt.show()

# %%
plt.pie(energy_consumption,labels=energy_sources,autopct='%1.1f%%')
plt.title('Energy Consumption by Source')
plt.show()

# %%
carbon_emission=[400,500,450,350,550]
plt.scatter(energy_consumption,carbon_emission)
plt.title('Energy Consumption vs Carbon Emission')
plt.xlabel('Energy Consumption (MWh)')
plt.ylabel('Carbon Emission (kg CO2)')
plt.show()

# %%
plt.barh(energy_sources,energy_consumption,color='orange',edgecolor='black',linewidth=2)
plt.title('Energy Consumption by Source',fontsize=14,fontweight='bold')
plt.xlabel('Energy Consumption (MWh)')
plt.ylabel('Energy Source')
plt.grid(True,linestyle='--',alpha=0.7)
plt.tight_layout()
plt.show()

# %%
import seaborn as sns
data = {
    "Solar": [1200, 1500, 1300],
    "Wind": [3400, 3600, 3200],
    "Hydropower": [2900, 3100, 2800],
    "Biomass": [2500, 2700, 2400]
}
df = pd.DataFrame(data)
# Create a pair plot
sns.pairplot(df)
plt.show()

# %%
correlation_matrix = df.corr()

# Plot heatmap
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=0.5)

# Add title
plt.title('Correlation Between Energy Sources')
plt.show()

# %%
sns.boxplot(x='Energy Source', y='Energy Consumption (MWh)', data=energy_df)
plt.title('Energy Consumption by Source')
plt.xlabel('Energy Source')
plt.ylabel('Energy Consumption (MWh)')
plt.show()

# %%
# Create a violin plot
sns.violinplot(data=df)

# Add title
plt.title('Violin Plot of Energy Consumption Distributions')
plt.show()

# %%
energy_values = [100, 200, 300, 400, 500]  # Replace with your actual data
carbon_emissions = [10, 20, 25, 40, 50]   # Replace with your actual data

# Create a DataFrame with energy consumption and carbon emissions
df_reg = pd.DataFrame({
    'Energy Consumption': energy_values,
    'Carbon Emissions': carbon_emissions
})

# Create a regression plot
sns.regplot(x='Energy Consumption', y='Carbon Emissions', data=df_reg)

# Add title
plt.title('Energy Consumption vs Carbon Emissions')
plt.xlabel('Energy Consumption')
plt.ylabel('Carbon Emissions')
plt.show()
